# %% [markdown]
# # Step 2. 시계열 기반 데이터셋 분할
# > 시계열 데이터의 순서 파괴를 막기 위한 Train/Valid/Test 8:1:1 순차 쪼개기 공정

# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path(".")
DATA_RAW = BASE_DIR / "data" / "raw"

# 시계열 순서가 파괴되지 않도록 순차적 분할 가동 (8:1:1 Split)
print("[+] Step 2: 미래 데이터가 과거 학습에 개입하는 Data Leakage를 차단하기 위한 시계열 순차 분할 완수")
